# %% [markdown]
# ## Python Project: File handling and string manipulation

# %% [markdown]
# A sample script of Game of Thrones was taken from the page and stored in the file conv.txt in
# the dataset provided.
#
# **Tasks:**
# 1. Find out the number of unique dialogue speakers in the sample conversation.
# 2. Create a new text file by the name of the dialogue speaker and store the unique words spoken by that character in the respective text file. Make sure there is only one wordevery line.

# %%
# importing required libraries
import string
from pprint import pprint

# %%
# Opening the text file in read only mode and adding each line to a list
with open('F:\\Python\\Python(Course 1)\\Project 1\\conv.txt', 'r') as f:
    lines = f.readlines()

# printing the lines in the file
pprint(lines)
# Out:
# ['WILL: Iâ€™ve never seen wildlings do a thing like this. Iâ€™ve never seen a '
#  'thing like this, not ever in my life.\n',
#  '\n',
#  'WAYMAR ROYCE: How close did you get?\n',
#  '\n',
#  'WILL: Close as any man would.\n',
#  '\n',
#  'GARED: We should head back to the wall.\n',
#  '\n',
#  'ROYCE: Do the dead frighten you?\n',
#  '\n',
#  'GARED: Our orders were to track the wildlings. We tracked them. They wonâ€™t '
#  'trouble us no more.\n',
#  '\n',
#  'ROYCE: You donâ€™t think heâ€™ll ask us how they died? Get back on your '
#  'horse.\n',
#  '\n',
#  'WILL: Whatever did it to them could do it to us. They even killed the '
#  'children.\n',
#  '\n',
#  'ROYCE: Itâ€™s a good thing weâ€™re not children. You want to run away south, '
#  'run away. Of course, they will behead you as a deserter â€¦ If I donâ€™t '
#  'catch you first. Get back on your horse. I wonâ€™t say it again.\n',
#  '\n',
#  'ROYCE: Your dead men seem to have moved camp.\n',
#  '\n',
#  'WILL: They were here.\n',
#  '\n',
#  'GARED: See where they went.\n',
#  '\n',
#  'ROYCE: What is it?\n',
#  '\n',
#  'JON: Go on. Fatherâ€™s watching.\n',
#  '\n',
#  'JON: And your mother.\n',
#  '\n',
#  'SEPTA MORDANE: Fine work, as always. Well done.\n',
#  '\n',
#  'SANSA: Thank you.\n',
#  '\n',
#  'SEPTA MORDANE: I love the detail that youâ€™ve managed to get in this '
#  'corners.\n',
#  '\n',
#  'NED: And which one of you was a marksman at ten? Keep practicing, Bran. Go '
#  'on.\n',
#  '\n',
#  'JON: Donâ€™t think too much, Bran.\n',
#  '\n',
#  'ROBB: Relax your bow arm.\n',
#  '\n',
#  'CASSEL: Lord Stark. My lady. A guardsman just rode in from the hills. '
#  'Theyâ€™ve captured a deserter from the Nightâ€™s Watch.\n',
#  '\n',
#  'NED: Get the lads to saddle their horses.\n',
#  '\n',
#  'CATELYN: Do you have to?\n',
#  '\n',
#  'NED: He swore an oath, Cat.\n',
#  '\n',
#  'CASSEL: The law is law, my lady.\n',
#  '\n',
#  'NED: Tell Bran heâ€™s coming, too.\n',
#  '\n',
#  'CATELYN: Ned. Ten is too young to see such things.\n',
#  '\n',
#  'NED: He wonâ€™t be a boy forever. And winter is coming.\n',
#  '\n',
#  'ROBB: Lad, go run back and get the rest.\n',
#  '\n',
#  'NED: King of the Andals and the First Men â€¦\n',
#  '\n',
#  'JON: Father will know if you do.\n',
#  '\n',
#  'NED: Lord of the Seven Kingdoms and protector of the realm, I, Eddard of the '
#  'House Stark, Lord of Winterfell and Warden of the North, sentence you to '
#  'die.\n',
#  '\n',
#  'JON: You did well.\n',
#  '\n',
#  'NED: You understand why I did it?\n',
#  '\n',
#  'BRAN: Jon said he was a deserter.\n',
#  '\n',
#  'NED: But do you understand why I had to kill him?\n',
#  '\n',
#  'BRAN: Our way is the old way?\n',
#  '\n',
#  'NED: The man who passes the sentence should swing the sword.\n',
#  '\n',
#  'BRAN: Is it true he saw the White Walkers?\n',
#  '\n',
#  'NED: The White Walkers have been gone for thousands of years.\n',
#  '\n',
#  'BRAN: So he was lying?\n',
#  '\n',
#  'NED: A madman sees what he sees.\n',
#  '\n',
#  'JON: What is it?\n',
#  '\n',
#  'THEON: Mountain lion?\n',
#  '\n',
#  'NED: There are no mountain lions in these woods.\n',
#  '\n',
#  'THEON: Itâ€™s a freak.\n',
#  '\n',
#  'NED: Itâ€™s a direwolf.\n',
#  '\n',
#  'NED: Tough old beast.\n',
#  '\n',
#  'ROBB: There are no direwolves south of the Wall.\n',
#  '\n',
#  'JON: Now there are five.\n',
#  '\n',
#  'JON: You want to hold it?\n',
#  '\n',
#  'BRAN: Where will they go? Their motherâ€™s dead.\n',
#  '\n',
#  'CASSEL: They donâ€™t belong down here.\n',
#  '\n',
#  'NED: Better a quick death. They wonâ€™t last without their mother.\n',
#  '\n',
#  'THEON: Right. Give it here.\n',
#  '\n',
#  'BRAN: NO!\n',
#  '\n',
#  'ROBB: Put away your blade.\n',
#  '\n',
#  'THEON: I take orders from your father, not you.\n',
#  '\n',
#  'BRAN: Please, father!\n',
#  '\n',
#  'NED: Iâ€™m sorry, Bran.\n',
#  '\n',
#  'JON: Lord Stark? There are five pups. One for each of the Stark children. '
#  'The direwolf is the sigil of your House. They were meant to have them.\n',
#  '\n',
#  'NED: You will train them yourselves. You will feed them yourselves. And if '
#  'they die, you will bury them yourselves.\n',
#  '\n',
#  'BRAN: What about you?\n',
#  '\n',
#  'JON: Iâ€™m not a Stark. Get on.\n',
#  '\n',
#  'ROBB: What is it?\n',
#  '\n',
#  'CERSEI: What if Jon Arryn told someone?\n',
#  '\n',
#  'JAIME: But who would he tell?\n',
#  '\n',
#  'CERSEI: My husband.\n',
#  '\n',
#  'JAIME: If he told the king, both our heads would be skewered on the city '
#  'gates by now. Whatever Jon Arryn knew or didnâ€™t know, it died with him. '
#  'And Robert will choose a new Hand of the king, someone to do his job while '
#  'heâ€™s off fucking boars and hunting whores. Or is it the other way around? '
#  'And life will go on.\n',
#  '\n',
#  'CERSEI: You should be the Hand of the king.\n',
#  '\n',
#  'JAIME: Thatâ€™s an honor I can do without. Their days are too long, their '
#  'lives are too short.\n',
#  '\n',
#  'CATELYN: All these years and I still feel like an outsider when I come '
#  'here.\n',
#  '\n',
#  'NED: You have five northern children. Youâ€™re not an outsider.\n',
#  '\n',
#  'CATELYN: I wonder if the old gods agree.\n',
#  '\n',
#  'NED: Itâ€™s your gods with all the rules.\n',
#  '\n',
#  'CATELYN: I am so sorry, my love.\n',
#  '\n',
#  'NED: Tell me.\n',
#  '\n',
#  'ROBB: I hear the prince is a right royal prick.\n',
#  '\n',
#  'THEON: Think of all those southern girls he gets to stab with his right '
#  'royal prick.\n',
#  '\n',
#  'ROBB: Go on, Tommy, shave him good. Heâ€™s never met a girl he likes better '
#  'than his own hair.\n',
#  '\n',
#  'CATELYN: Gods, but they grow fast.\n',
#  '\n',
#  'BRAN: I saw the king! Heâ€™s got hundreds of people!\n',
#  '\n',
#  'CATELYN: How many times have I told you No climbing!\n',
#  '\n',
#  'BRAN: But heâ€™s coming right now! Down our road!\n',
#  '\n',
#  'CATELYN: I want you to promise me. No more climbing.\n',
#  '\n',
#  'NED: Your Grace.\n',
#  '\n',
#  'ROBERT: Youâ€™ve got fat.\n',
#  '\n',
#  'ROBERT: Cat!\n',
#  '\n',
#  'CATELYN: Your Grace.\n',
#  '\n',
#  'ROBERT: Nine years. Why havenâ€™t I seen you? Where the hell have you '
#  'been?\n',
#  '\n',
#  'NED: Guarding the North for you, Your Grace. Winterfell is yours.\n',
#  '\n',
#  'ARYA: Whereâ€™s the Imp?\n',
#  '\n',
#  'SANSA: Will you shut up?\n',
#  '\n',
#  'ROBERT: Who have we here? You must be Robb.\n',
#  '\n',
#  'ARYA: Arya.\n',
#  '\n',
#  'ROBERT: Ooh. Show us your muscles. Youâ€™ll be a soldier.\n',
#  '\n',
#  'ARYA: Thatâ€™s Jaime Lannister. The queenâ€™s twin brother.\n',
#  '\n',
#  'SANSA: Would you please shut up.\n',
#  '\n',
#  'NED: My queen.\n',
#  '\n',
#  'CATELYN: My queen.\n',
#  '\n',
#  'ROBERT: Take me to your crypt. I want to pay my respects.\n',
#  '\n',
#  'CERSEI: Weâ€™ve been riding for a month, my love. Surely the dead can '
#  'wait.\n',
#  '\n',
#  'ROBERT: Ned.\n',
#  '\n',
#  'ARYA: Whereâ€™s the Imp?\n',
#  '\n',
#  'CERSEI: Where is our brother? Go find the little beast.\n',
#  '\n',
#  'NED: Tell me about Jon Arryn.\n',
#  '\n',
#  'ROBERT: One minute he was fine, and then â€¦ Burned right through him, '
#  'whatever it was. I loved that man.\n',
#  '\n',
#  'NED: We both did.\n',
#  '\n',
#  'ROBERT: He never had to teach you much, but me â€¦ You remember me at 16? '
#  'All I wanted to do was crack skulls and fuck girls. He showed me what was '
#  'what.\n',
#  '\n',
#  'NED: Aye.\n',
#  '\n']

# %%
# total number of lines in the text file
print("Number of lines in the file is:",(len(lines)))
# Out:
# Number of lines in the file is: 222

# %%
# removing the blank lines
for line in lines:
    if line == '\n':
        lines.remove(line)

pprint(lines)
# Out:
# ['WILL: Iâ€™ve never seen wildlings do a thing like this. Iâ€™ve never seen a '
#  'thing like this, not ever in my life.\n',
#  'WAYMAR ROYCE: How close did you get?\n',
#  'WILL: Close as any man would.\n',
#  'GARED: We should head back to the wall.\n',
#  'ROYCE: Do the dead frighten you?\n',
#  'GARED: Our orders were to track the wildlings. We tracked them. They wonâ€™t '
#  'trouble us no more.\n',
#  'ROYCE: You donâ€™t think heâ€™ll ask us how they died? Get back on your '
#  'horse.\n',
#  'WILL: Whatever did it to them could do it to us. They even killed the '
#  'children.\n',
#  'ROYCE: Itâ€™s a good thing weâ€™re not children. You want to run away south, '
#  'run away. Of course, they will behead you as a deserter â€¦ If I donâ€™t '
#  'catch you first. Get back on your horse. I wonâ€™t say it again.\n',
#  'ROYCE: Your dead men seem to have moved camp.\n',
#  'WILL: They were here.\n',
#  'GARED: See where they went.\n',
#  'ROYCE: What is it?\n',
#  'JON: Go on. Fatherâ€™s watching.\n',
#  'JON: And your mother.\n',
#  'SEPTA MORDANE: Fine work, as always. Well done.\n',
#  'SANSA: Thank you.\n',
#  'SEPTA MORDANE: I love the detail that youâ€™ve managed to get in this '
#  'corners.\n',
#  'NED: And which one of you was a marksman at ten? Keep practicing, Bran. Go '
#  'on.\n',
#  'JON: Donâ€™t think too much, Bran.\n',
#  'ROBB: Relax your bow arm.\n',
#  'CASSEL: Lord Stark. My lady. A guardsman just rode in from the hills. '
#  'Theyâ€™ve captured a deserter from the Nightâ€™s Watch.\n',
#  'NED: Get the lads to saddle their horses.\n',
#  'CATELYN: Do you have to?\n',
#  'NED: He swore an oath, Cat.\n',
#  'CASSEL: The law is law, my lady.\n',
#  'NED: Tell Bran heâ€™s coming, too.\n',
#  'CATELYN: Ned. Ten is too young to see such things.\n',
#  'NED: He wonâ€™t be a boy forever. And winter is coming.\n',
#  'ROBB: Lad, go run back and get the rest.\n',
#  'NED: King of the Andals and the First Men â€¦\n',
#  'JON: Father will know if you do.\n',
#  'NED: Lord of the Seven Kingdoms and protector of the realm, I, Eddard of the '
#  'House Stark, Lord of Winterfell and Warden of the North, sentence you to '
#  'die.\n',
#  'JON: You did well.\n',
#  'NED: You understand why I did it?\n',
#  'BRAN: Jon said he was a deserter.\n',
#  'NED: But do you understand why I had to kill him?\n',
#  'BRAN: Our way is the old way?\n',
#  'NED: The man who passes the sentence should swing the sword.\n',
#  'BRAN: Is it true he saw the White Walkers?\n',
#  'NED: The White Walkers have been gone for thousands of years.\n',
#  'BRAN: So he was lying?\n',
#  'NED: A madman sees what he sees.\n',
#  'JON: What is it?\n',
#  'THEON: Mountain lion?\n',
#  'NED: There are no mountain lions in these woods.\n',
#  'THEON: Itâ€™s a freak.\n',
#  'NED: Itâ€™s a direwolf.\n',
#  'NED: Tough old beast.\n',
#  'ROBB: There are no direwolves south of the Wall.\n',
#  'JON: Now there are five.\n',
#  'JON: You want to hold it?\n',
#  'BRAN: Where will they go? Their motherâ€™s dead.\n',
#  'CASSEL: They donâ€™t belong down here.\n',
#  'NED: Better a quick death. They wonâ€™t last without their mother.\n',
#  'THEON: Right. Give it here.\n',
#  'BRAN: NO!\n',
#  'ROBB: Put away your blade.\n',
#  'THEON: I take orders from your father, not you.\n',
#  'BRAN: Please, father!\n',
#  'NED: Iâ€™m sorry, Bran.\n',
#  'JON: Lord Stark? There are five pups. One for each of the Stark children. '
#  'The direwolf is the sigil of your House. They were meant to have them.\n',
#  'NED: You will train them yourselves. You will feed them yourselves. And if '
#  'they die, you will bury them yourselves.\n',
#  'BRAN: What about you?\n',
#  'JON: Iâ€™m not a Stark. Get on.\n',
#  'ROBB: What is it?\n',
#  'CERSEI: What if Jon Arryn told someone?\n',
#  'JAIME: But who would he tell?\n',
#  'CERSEI: My husband.\n',
#  'JAIME: If he told the king, both our heads would be skewered on the city '
#  'gates by now. Whatever Jon Arryn knew or didnâ€™t know, it died with him. '
#  'And Robert will choose a new Hand of the king, someone to do his job while '
#  'heâ€™s off fucking boars and hunting whores. Or is it the other way around? '
#  'And life will go on.\n',
#  'CERSEI: You should be the Hand of the king.\n',
#  'JAIME: Thatâ€™s an honor I can do without. Their days are too long, their '
#  'lives are too short.\n',
#  'CATELYN: All these years and I still feel like an outsider when I come '
#  'here.\n',
#  'NED: You have five northern children. Youâ€™re not an outsider.\n',
#  'CATELYN: I wonder if the old gods agree.\n',
#  'NED: Itâ€™s your gods with all the rules.\n',
#  'CATELYN: I am so sorry, my love.\n',
#  'NED: Tell me.\n',
#  'ROBB: I hear the prince is a right royal prick.\n',
#  'THEON: Think of all those southern girls he gets to stab with his right '
#  'royal prick.\n',
#  'ROBB: Go on, Tommy, shave him good. Heâ€™s never met a girl he likes better '
#  'than his own hair.\n',
#  'CATELYN: Gods, but they grow fast.\n',
#  'BRAN: I saw the king! Heâ€™s got hundreds of people!\n',
#  'CATELYN: How many times have I told you No climbing!\n',
#  'BRAN: But heâ€™s coming right now! Down our road!\n',
#  'CATELYN: I want you to promise me. No more climbing.\n',
#  'NED: Your Grace.\n',
#  'ROBERT: Youâ€™ve got fat.\n',
#  'ROBERT: Cat!\n',
#  'CATELYN: Your Grace.\n',
#  'ROBERT: Nine years. Why havenâ€™t I seen you? Where the hell have you '
#  'been?\n',
#  'NED: Guarding the North for you, Your Grace. Winterfell is yours.\n',
#  'ARYA: Whereâ€™s the Imp?\n',
#  'SANSA: Will you shut up?\n',
#  'ROBERT: Who have we here? You must be Robb.\n',
#  'ARYA: Arya.\n',
#  'ROBERT: Ooh. Show us your muscles. Youâ€™ll be a soldier.\n',
#  'ARYA: Thatâ€™s Jaime Lannister. The queenâ€™s twin brother.\n',
#  'SANSA: Would you please shut up.\n',
#  'NED: My queen.\n',
#  'CATELYN: My queen.\n',
#  'ROBERT: Take me to your crypt. I want to pay my respects.\n',
#  'CERSEI: Weâ€™ve been riding for a month, my love. Surely the dead can '
#  'wait.\n',
#  'ROBERT: Ned.\n',
#  'ARYA: Whereâ€™s the Imp?\n',
#  'CERSEI: Where is our brother? Go find the little beast.\n',
#  'NED: Tell me about Jon Arryn.\n',
#  'ROBERT: One minute he was fine, and then â€¦ Burned right through him, '
#  'whatever it was. I loved that man.\n',
#  'NED: We both did.\n',
#  'ROBERT: He never had to teach you much, but me â€¦ You remember me at 16? '
#  'All I wanted to do was crack skulls and fuck girls. He showed me what was '
#  'what.\n',
#  'NED: Aye.\n']

# %%
# printing number of lines after removing blank lines
print('Number of lines with dialogues: ',len(lines))
# Out:
# Number of lines with dialogues:  111

# %%
# initializing an empty set
characters = set()

# using for loop to loop through the list and extracting each character's name,and adding them to a set
for line in lines:
    for char in line:
        if char == ':':        # searching for the special character ':' in each dialogue
            index = line.index(char)
            characters.add(line[0:index])        # extracting the name of the Character and adding it to the set
            break

# %%
# removing the duplicate characters but with different name
characters.remove('WAYMAR ROYCE')        # 'WAYMAR ROYCE' and 'ROYCE', being the same character

# %%
# printing the names of the unique characters 
print('The unique characters in the script are:')
pprint(characters)

# printing the number of unique characters
print('\nThe number of unique characters in the script is:',len(characters))
# Out:
# The unique characters in the script are:
# {'ARYA',
#  'BRAN',
#  'CASSEL',
#  'CATELYN',
#  'CERSEI',
#  'GARED',
#  'JAIME',
#  'JON',
#  'NED',
#  'ROBB',
#  'ROBERT',
#  'ROYCE',
#  'SANSA',
#  'SEPTA MORDANE',
#  'THEON',
#  'WILL'}
#
# The number of unique characters in the script is: 16

# %%
'''
Defining a function to extract unique words said by each character.
Taking in the name of the Character as the parameter and the extracting the unique words spoken by the character
and putting them in a list for each Character.
'''
def unique_words(name):
    words = list()
    
    # splitting each line into words and adding to a list
    for line in lines:
        index = line.index(':')        # starting index
        line = line.translate(str.maketrans('', '', string.punctuation))        # removing the punctuations from each line
        line = line.strip()        # removes the leading and trailing white spaces
        
        if name in line:
            words.extend(line[index+1:].split(' '))        # Adding the words spoken by the Character to the list of words
    
    # converting the list of words into a set to get the unique words
    words = set(words)
    print(name,words)
    
    return(words)

# %%
# defining a function to write the unique words said by each character in a different text file
def write_file(name):
    file_path = 'F:\\Python\\Python(Course 1)\\Project 1\\' + name +'.txt'        # setting the file path with the name as the name of each Character
    file = open(file_path,'a')
    
    words = unique_words(name)        # getting the unique words using the function we defined

    for word in words:
        file.write(word +'\n')        # writing each word in the file in a new line
    
    print(f'Unique words of {name} written in the text file')
    print('Total number of unique words:',len(words),'\n')
    
    # closing the file
    file.close()

# %%
# writing the unique words of each character using the defined function
for character in characters:
    write_file(character)
# Out:
# WILL {'They', 'to', 'it', 'seen', 'here', 'could', 'even', 'man', 'in', 'as', 'the', 'this', 'wildlings', 'Close', 'would', 'did', 'killed', 'do', 'Iâ€™ve', 'a', 'any', 'Whatever', 'like', 'life', 'thing', 'never', 'not', 'us', 'ever', 'my', 'were', 'them', 'children'}
# Unique words of WILL written in the text file
# Total number of unique words: 33
#
# JAIME {'told', 'didnâ€™t', 'If', 'knew', 'to', 'know', 'it', 'And', 'him', 'hunting', 'he', 'Jon', 'with', 'someone', 'go', 'on', 'our', 'Their', 'or', 'other', 'their', 'lives', 'Thatâ€™s', 'short', 'choose', 'can', 'an', 'the', 'Arryn', 'boars', 'would', 'who', 'and', 'both', 'do', 'Robert', 'will', 'died', 'a', 'fucking', 'Whatever', 'king', 'skewered', 'But', 'his', 'city', 'of', 'while', 'around', 'too', 'tell', 'way', 'Or', 'by', 'life', 'heâ€™s', 'honor', 'long', 'new', 'job', 'gates', 'whores', 'are', 'off', 'be', 'Hand', 'I', 'without', 'days', 'now', 'heads', 'is'}
# Unique words of JAIME written in the text file
# Total number of unique words: 72
#
# JON {'They', 'there', 'to', 'know', 'And', 'it', 'pups', 'well', 'Iâ€™m', 'You', 'Go', 'on', 'mother', 'The', 'hold', 'the', 'your', 'did', 'One', 'do', 'Bran', 'a', 'will', 'House', 'want', 'have', 'think', 'of', 'too', 'Get', 'direwolf', 'Donâ€™t', 'you', 'There', 'What', 'Father', 'Stark', 'not', 'five', 'Fatherâ€™s', 'are', 'were', 'each', 'for', 'them', 'Lord', 'sigil', 'much', 'meant', 'Now', 'if', 'is', 'children', 'watching'}
# Unique words of JON written in the text file
# Total number of unique words: 54
#
# SEPTA MORDANE {'as', 'done', 'detail', 'get', 'to', 'always', 'the', 'youâ€™ve', 'managed', 'this', 'Fine', 'corners', 'I', 'in', 'Well', 'work', 'that', 'love'}
# Unique words of SEPTA MORDANE written in the text file
# Total number of unique words: 18
#
# BRAN {'Heâ€™s', 'now', 'Is', 'it', 'Where', 'he', 'Jon', 'old', 'father', 'go', 'road', 'White', 'dead', 'Their', 'our', 'they', 'hundreds', 'the', 'lying', 'Walkers', 'a', 'will', 'So', 'saw', 'king', 'But', 'deserter', 'of', 'NO', 'Our', 'Please', 'way', 'you', 'about', 'heâ€™s', 'What', 'was', 'motherâ€™s', 'true', 'said', 'Down', 'people', 'got', 'right', 'I', 'coming', 'is'}
# Unique words of BRAN written in the text file
# Total number of unique words: 47
#
# NED {'They', 'sees', 'Youâ€™re', 'Seven', 'me', 'man', 'rules', 'madman', 'â€¦', 'The', 'train', 'an', 'the', 'thousands', 'what', 'your', 'Walkers', 'which', 'who', 'both', 'Bran', 'a', 'will', 'House', 'But', 'Cat', 'of', 'Eddard', 'North', 'We', 'too', 'direwolf', 'lads', 'had', 'Stark', 'gods', 'understand', 'gone', 'winter', 'My', 'if', 'Aye', 'why', 'should', 'been', 'old', 'passes', 'Iâ€™m', 'on', 'Go', 'beast', 'and', 'Arryn', 'did', 'do', 'Keep', 'have', 'yours', 'swing', 'Guarding', 'last', 'you', 'five', 'ten', 'years', 'for', 'without', 'marksman', 'He', 'is', 'children', 'oath', 'Itâ€™s', 'no', 'to', 'realm', 'And', 'with', 'saddle', 'You', 'Andals', 'swore', 'White', 'Warden', 'horses', 'yourselves', 'forever', 'sorry', 'outsider', 'these', 'all', 'There', 'kill', 'sword', 'Tell', 'woods', 'are', 'be', 'wonâ€™t', 'quick', 'Your', 'them', 'coming', 'Men', 'Better', 'boy', 'practicing', 'northern', 'it', 'one', 'protector', 'him', 'he', 'bury', 'die', 'Jon', 'King', 'in', 'lions', 'A', 'mother', 'their', 'they', 'Kingdoms', 'queen', 'Tough', 'death', 'Grace', 'feed', 'Get', 'First', 'heâ€™s', 'about', 'was', 'not', 'sentence', 'mountain', 'Lord', 'Winterfell', 'I', 'at'}
# Unique words of NED written in the text file
# Total number of unique words: 141
#
# THEON {'freak', 'Itâ€™s', 'those', 'Think', 'to', 'it', 'from', 'here', 'he', 'father', 'with', 'gets', 'Right', 'your', 'girls', 'royal', 'a', 'his', 'Mountain', 'of', 'all', 'prick', 'you', 'southern', 'not', 'Give', 'lion', 'stab', 'right', 'I', 'orders', 'take'}
# Unique words of THEON written in the text file
# Total number of unique words: 32
#
# SANSA {'Will', 'Thank', 'shut', 'please', 'up', 'you', 'Would'}
# Unique words of SANSA written in the text file
# Total number of unique words: 7
#
# CERSEI {'told', 'Surely', 'month', 'should', 'Where', 'been', 'Jon', 'someone', 'You', 'dead', 'our', 'Go', 'little', 'beast', 'the', 'Arryn', 'a', 'can', 'king', 'of', 'find', 'wait', 'brother', 'What', 'riding', 'Weâ€™ve', 'My', 'husband', 'my', 'be', 'Hand', 'for', 'if', 'is', 'love'}
# Unique words of CERSEI written in the text file
# Total number of unique words: 35
#
# CASSEL {'They', 'from', 'here', 'guardsman', 'in', 'A', 'The', 'lady', 'rode', 'down', 'the', 'a', 'hills', 'Nightâ€™s', 'deserter', 'Theyâ€™ve', 'Watch', 'law', 'Stark', 'donâ€™t', 'just', 'My', 'my', 'captured', 'Lord', 'is', 'belong'}
# Unique words of CASSEL written in the text file
# Total number of unique words: 27
#
# GARED {'They', 'no', 'to', 'where', 'should', 'they', 'the', 'wildlings', 'track', 'more', 'wall', 'We', 'Our', 'back', 'went', 'trouble', 'us', 'were', 'See', 'wonâ€™t', 'tracked', 'them', 'orders', 'head'}
# Unique words of GARED written in the text file
# Total number of unique words: 24
#
# ROBERT {'fat', 'loved', 'must', 'to', 'Burned', 'it', 'hell', 'here', 'seen', 'Where', 'been', 'Ooh', 'me', 'Ned', 'crypt', 'he', 'him', 'whatever', '16', 'man', 'You', 'â€¦', 'Show', 'but', 'fine', 'All', 'the', 'your', 'and', 'what', 'Youâ€™ve', 'havenâ€™t', 'Youâ€™ll', 'respects', 'One', 'a', 'minute', 'do', 'girls', 'wanted', 'want', 'pay', 'have', 'Cat', 'through', 'soldier', 'showed', 'muscles', 'we', 'crack', 'you', 'much', 'Robb', 'was', 'never', 'had', 'Nine', 'Take', 'us', 'that', 'teach', 'remember', 'skulls', 'years', 'my', 'Why', 'got', 'Who', 'be', 'fuck', 'right', 'at', 'I', 'He', 'then'}
# Unique words of ROBERT written in the text file
# Total number of unique words: 75
#
# ROYCE {'Itâ€™s', 'If', 'heâ€™ll', 'to', 'it', 'Do', 'again', 'get', 'You', 'dead', 'on', 'as', 'â€¦', 'they', 'catch', 'is', 'moved', 'weâ€™re', 'the', 'your', 'did', 'south', 'a', 'will', 'died', 'behead', 'how', 'want', 'seem', 'have', 'close', 'think', 'deserter', 'ask', 'frighten', 'Get', 'back', 'you', 'thing', 'What', 'Of', 'course', 'not', 'donâ€™t', 'children', 'us', 'run', 'men', 'good', 'horse', 'Your', 'wonâ€™t', 'say', 'I', 'camp', 'away', 'How', 'first'}
# Unique words of ROYCE written in the text file
# Total number of unique words: 58
#
# ARYA {'Jaime', 'Imp', 'The', 'Thatâ€™s', 'Lannister', 'brother', 'the', 'Arya', 'Whereâ€™s', 'twin', 'queenâ€™s'}
# Unique words of ARYA written in the text file
# Total number of unique words: 11
#
# CATELYN {'told', 'No', 'to', 'here', 'me', 'Do', 'Ned', 'old', 'agree', 'many', 'they', 'Gods', 'but', 'things', 'an', 'All', 'the', 'and', 'queen', 'still', 'young', 'want', 'have', 'come', 'like', 'more', 'Grace', 'too', 'Ten', 'sorry', 'outsider', 'such', 'these', 'fast', 'you', 'when', 'gods', 'so', 'times', 'wonder', 'feel', 'am', 'climbing', 'My', 'years', 'my', 'Your', 'grow', 'see', 'promise', 'I', 'if', 'is', 'How', 'love'}
# Unique words of CATELYN written in the text file
# Total number of unique words: 55
#
# ROBB {'hair', 'no', 'Heâ€™s', 'it', 'him', 'he', 'get', 'likes', 'go', 'Relax', 'than', 'Wall', 'Go', 'on', 'hear', 'is', 'the', 'your', 'and', 'blade', 'south', 'Put', 'royal', 'a', 'his', 'of', 'back', 'prick', 'There', 'rest', 'What', 'direwolves', 'never', 'shave', 'run', 'prince', 'met', 'good', 'Lad', 'are', 'bow', 'Tommy', 'girl', 'own', 'better', 'right', 'I', 'arm', 'away'}
# Unique words of ROBB written in the text file
# Total number of unique words: 49
